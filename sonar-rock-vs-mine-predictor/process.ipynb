# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
sonar_data = pd.read_csv("data/Copy of sonar data.csv")
sonar_data.head()
# Out:
#    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
#
#    0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  \
# 0  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 1  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 2  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 3  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
# 4  0.3039  ...  0.0045  0.0014  0.0038  0.0013  0.0089  0.0057  0.0027
#
#    0.0090  0.0032  R
# 0  0.0052  0.0044  R
# 1  0.0095  0.0078  R
# 2  0.0040  0.0117  R
# ...

# %%
sonar_data.shape
# Out:
# (207, 61)

# %%
sonar_data.iloc[:,60].value_counts()
# Out:
# R
# M    111
# R     96
# Name: count, dtype: int64

# %%
sonar_data_values = sonar_data.iloc[:,:60]
sonar_data_labels = sonar_data.iloc[:,-1]

sonar_data_values
# Out:
#      0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
sonar_data_labels
# Out:
# 0      R
# 1      R
# 2      R
# 3      R
# 4      R
#       ..
# 202    M
# 203    M
# 204    M
# 205    M
# 206    M
# Name: R, Length: 207, dtype: object

# %%
values_train, values_test, labels_train, labels_test = train_test_split(sonar_data_values, sonar_data_labels, test_size=0.1, stratify=sonar_data_labels, random_state=1)
print("Values : " , sonar_data_values.shape, values_train.shape, values_test.shape)
print("Labels : ", sonar_data_labels.shape, values_train.shape, values_test.shape)

print("Values Train : ", values_train.shape)
print("Labels Train : ", labels_train.shape)
print("Values Test : ", values_test.shape)
print("Labels Test : ", labels_test.shape)
# Out:
# Values :  (207, 60) (186, 60) (21, 60)
# Labels :  (207,) (186, 60) (21, 60)
# Values Train :  (186, 60)
# Labels Train :  (186,)
# Values Test :  (21, 60)
# Labels Test :  (21,)

# %%
model = LogisticRegression()
model.fit(values_train, labels_train)
# Out:
# LogisticRegression()

# %%
print(values_train)
print(labels_train)
# Out:
#      0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 114  0.0414  0.0436  0.0447  0.0844  0.0419  0.1215  0.2002  0.1516  0.0818
# 65   0.0265  0.0440  0.0137  0.0084  0.0305  0.0438  0.0341  0.0780  0.0844
# 16   0.0192  0.0607  0.0378  0.0774  0.1388  0.0809  0.0568  0.0219  0.1037
# 122  0.0270  0.0163  0.0341  0.0247  0.0822  0.1256  0.1323  0.1584  0.2017
# 36   0.0333  0.0221  0.0270  0.0481  0.0679  0.0981  0.0843  0.1172  0.0759
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 139  0.0412  0.1135  0.0518  0.0232  0.0646  0.1124  0.1787  0.2407  0.2682
# 15   0.0352  0.0116  0.0191  0.0469  0.0737  0.1185  0.1683  0.1541  0.1466
# 153  0.0117  0.0069  0.0279  0.0583  0.0915  0.1267  0.1577  0.1927  0.2361
# 130  0.1150  0.1163  0.0866  0.0358  0.0232  0.1267  0.2417  0.2661  0.4346
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
#
# ...

# %%
values_train_prediction = model.predict(values_train)
training_data_accuracy = accuracy_score(values_train_prediction, labels_train)

# %%
print("Accuracy : " , training_data_accuracy)
# Out:
# Accuracy :  0.8440860215053764

# %%
values_test_prediction = model.predict(values_test)
test_data_accuracy = accuracy_score(values_test_prediction, labels_test)

# %%
print("Accuracy : " , test_data_accuracy)
# Out:
# Accuracy :  0.7619047619047619

# %% [markdown]
# ### Making a predictive model and testing on generated

# %%
#GPT generated
import numpy as np

# Define the min and max ranges based on the provided data
min_values = np.array([0.0000, 0.0013, 0.0018, 0.0041, 0.0048, 0.0050, 0.0063, 0.0081, 0.0111, 0.0137, 0.0140, 0.0142, 0.0145, 0.0146, 0.0154, 0.0161, 0.0164, 0.0180, 0.0181, 0.0193, 0.0194, 0.0204, 0.0210, 0.0223, 0.0231, 0.0233, 0.0237, 0.0252, 0.0255, 0.0268, 0.0279, 0.0317, 0.0332, 0.0346, 0.0361, 0.0362, 0.0374, 0.0400, 0.0421, 0.0439, 0.0473, 0.0491, 0.0521, 0.0536, 0.0592, 0.0653, 0.0665, 0.0741, 0.0747, 0.0762, 0.0768, 0.0794, 0.0809, 0.0863, 0.0898, 0.0904, 0.0942, 0.0956, 0.0990])
max_values = np.array([0.9036, 0.7812, 0.7520, 0.7563, 0.6903, 0.6532, 0.6520, 0.6385, 0.6359, 0.6176, 0.6079, 0.5900, 0.5581, 0.5517, 0.5372, 0.5354, 0.5340, 0.5323, 0.5300, 0.5255, 0.5228, 0.5200, 0.5070, 0.4995, 0.4900, 0.4766, 0.4577, 0.4572, 0.4468, 0.4181, 0.4091, 0.4086, 0.4024, 0.3987, 0.3907, 0.3784, 0.3725, 0.3714, 0.3660, 0.3652, 0.3624, 0.3603, 0.3470, 0.3476, 0.3456, 0.3340, 0.3323, 0.3290, 0.3264, 0.3262, 0.3235, 0.3195, 0.3176, 0.3111, 0.3059, 0.2995, 0.2948, 0.2975, 0.2947])

# Generate two rows of values within these ranges
np.random.seed(42)  # For reproducibility
generated_values = np.random.uniform(min_values, max_values, (2, 59))

print("Generated Values:")
print(generated_values)
# Out:
# Generated Values:
# [[0.33843445 0.74276209 0.55094186 0.45441091 0.11175078 0.10611565
#   0.04380459 0.55413744 0.38667666 0.44130503 0.02622513 0.57267409
#   0.46701582 0.12864734 0.11027627 0.11134196 0.17387578 0.28788223
#   0.23921266 0.16672019 0.32740675 0.09009113 0.1629823  0.19712787
#   0.23603908 0.37922026 0.11035842 0.24734928 0.27508426 0.04497605
#   0.2594961  0.09597054 0.05721705 0.38008922 0.37851312 0.31283357
#   0.13947607 0.07236854 0.26372308 0.185321   0.08575425 0.20319905
#   0.06224117 0.3209402  0.13331459 0.24331974 0.1493528  0.20666534
#   0.21230698 0.12241361 0.31599653 0.26550939 0.3032794  0.28745719
#   0.21900619 0.2831639  0.1119516  0.13516894 0.10785098]
#  [0.29396849 0.30442942 0.20536604 0.62747635 0.24935441 0.18710175
#   0.35671886 0.09693863 0.51231267 0.05872113 0.60011215 0.45885854
#   0.12252184 0.01756593 0.44090777 0.38317102 0.39373411 0.41466434
#   0.05600346 0.20075535 0.07772848 0.45160647 0.32392289 0.18020454
# ...

# %%
# copied data from Line 98 of sonar_data.
# input_data = (0.0491,0.0279,0.0592,0.1270,0.1772,0.1908,0.2217,0.0768,0.1246,0.2028,0.0947,0.2497,0.2209,0.3195,0.3340,0.3323,0.2780,0.2975,0.2948,0.1729,0.3264,0.3834,0.3523,0.5410,0.5228,0.4475,0.5340,0.5323,0.3907,0.3456,0.4091,0.4639,0.5580,0.5727,0.6355,0.7563,0.6903,0.6176,0.5379,0.5622,0.6508,0.4797,0.3736,0.2804,0.1982,0.2438,0.1789,0.1706,0.0762,0.0238,0.0268,0.0081,0.0129,0.0161,0.0063,0.0119,0.0194,0.0140,0.0332,0.0439)
# th above data is for a mine, but it predicts that it is rock.
input_data = (0.0712,0.0901,0.1276,0.1497,0.1284,0.1165,0.1285,0.1684,0.1830,0.2127,0.2891,0.3985,0.4576,0.5821,0.5027,0.1930,0.2579,0.3177,0.2745,0.6186,0.8958,0.7442,0.5188,0.2811,0.1773,0.6607,0.7576,0.5122,0.4701,0.5479,0.4347,0.1276,0.0846,0.0927,0.0313,0.0998,0.1781,0.1586,0.3001,0.2208,0.1455,0.2895,0.3203,0.1414,0.0629,0.0734,0.0805,0.0608,0.0565,0.0286,0.0154,0.0154,0.0156,0.0054,0.0030,0.0048,0.0087,0.0101,0.0095,0.0068)
input_data_as_numpy_array = np.asarray(input_data)
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)
prediction = model.predict(input_data_reshaped)
if (prediction[0] == 'R'):
    print("The object is a Rock")
else:
    print("The object is a Mine")
# Out:
# The object is a Mine
# C:\Users\anant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
